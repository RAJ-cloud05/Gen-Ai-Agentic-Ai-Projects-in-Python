# %% [markdown]
# # IMAGE TO ARRAY

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt    #used for visualization

# %%
from PIL import Image    #python image library

# %%
image=Image.open(r"C:\Users\Raj Vishwakarma\OneDrive\Desktop\image.jpg")

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=243x148>

# %%
type(image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
ia= np.asarray(image)   #converts image to array
ia
# Out:
# array([[[ 71, 111,  76],
#         [ 73, 114,  72],
#         [ 75, 119,  70],
#         ...,
#         [145, 174, 170],
#         [145, 174, 170],
#         [145, 174, 170]],
#
#        [[ 71, 111,  76],
#         [ 73, 114,  74],
#         [ 75, 119,  70],
#         ...,
#         [145, 174, 170],
#         [145, 174, 170],
#         [145, 174, 170]],
#
#        [[ 71, 111,  76],
#         [ 73, 114,  74],
#         [ 75, 119,  70],
#         ...,
#         [145, 174, 170],
#         [145, 174, 170],
#         [145, 174, 170]],
#
#        ...,
#
#        [[107, 171, 145],
#         [106, 170, 146],
#         [105, 169, 145],
#         ...,
#         [ 89, 182, 111],
#         [ 89, 182, 111],
#         [ 89, 182, 111]],
#
#        [[111, 175, 149],
#         [110, 174, 150],
#         [109, 173, 149],
#         ...,
#         [ 89, 182, 111],
#         [ 89, 182, 111],
#         [ 89, 182, 111]],
#
#        [[113, 177, 151],
#         [112, 176, 152],
#         [111, 175, 151],
# ...

# %%
plt.imshow(image)
plt.show()

# %%
ia.shape
# Out:
# (148, 243, 3)
