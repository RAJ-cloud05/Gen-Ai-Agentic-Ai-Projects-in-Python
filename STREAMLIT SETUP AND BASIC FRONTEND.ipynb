# %% [markdown]
# # STREAMLIT SETUP

# %% [raw]
# => STREAMLIT IS USED FOR BUILDING THE FRONTEND
# ----------------------------------------------------
# => pip install streamlit
# => import streamlit as st
# => st.write("WELCOME")
# => SAVE THE FILE AS ".py" EXTENSION
# => OPEN CMD AND GOTO SAVED LOCATION
# => streamlit run filename
