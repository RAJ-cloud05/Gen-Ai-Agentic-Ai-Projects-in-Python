# %% [markdown]
# # PYTHON SET DATA STRUCTURE

# %% [raw]
# => set data type symbol = "{}" or "curly braces"
# => no duplicates allowed
# => no indexing and slicing allowed

# %%
s={1,2,3,10,8,29,21,39}

# %%
s.add(20)   #it adds the value
s
# Out:
# {1, 2, 3, 8, 10, 20, 21, 29, 39}

# %%
s2=s.copy()
s2
# Out:
# {1, 2, 3, 8, 10, 20, 21, 29, 39}

# %%
s.pop()
s
# Out:
# {2, 3, 8, 10, 20, 21, 29, 39}

# %%
s.pop()
# Out:
# 2

# %%
s.add(1)
s
# Out:
# {1, 3, 8, 10, 20, 21, 29, 39}

# %%
s3={1,2,3}
s4={3,4,5,6,7}
s5={6,8,9,10,11}

# %%
s3.difference(s4)
# Out:
# {1, 2}

# %%
s4.difference_update(s5)

# %%
s4.intersection(s5)
# Out:
# set()

# %%
s4.isdisjoint(2)
