# %% [markdown]
# PYTHON TYPECASTING TECHNIQUES !!!

# %% [raw]
# => INT TO ALL OTHER DATA TPYES

# %%
int(10)
# Out:
# 10

# %%
int(10.2)
# Out:
# 10

# %%
int(10.2,15.8)      # ONLY ONE ARGUMENT AT A TIME
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 int(10.2,15.8)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(1+3j)    # TYPE CONVERSION FOR INT --> COMPLEX NOT POSSIBLE
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 int(1+3j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('10')
# Out:
# 10

# %%
int('raj')       # type conversion of str to int is possible for exact value not for the text value
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 int('raj')
#
# ValueError: invalid literal for int() with base 10: 'raj'

# %%
int('10.2')     #conversion only possible for whole numbers
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 int('10.2')
#
# ValueError: invalid literal for int() with base 10: '10.2'

# %% [raw]
# => FLOAT TO ALL OTHER DATA TYPES

# %%
float(10)
# Out:
# 10.0

# %%
float(9.666)
# Out:
# 9.666

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
float(1+3j)    # TYPE CASTING FROM COMPLEX --> FLOAT IS ALSO NOT POSSIBLE
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 float(1+3j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float('10')
# Out:
# 10.0

# %%
float('10.9')
# Out:
# 10.9

# %%
float('raj')      #FLOAT CONVERSION POSSIBLE FOR WHOLE NUMBERS AND INTEGERS NUMBER BOTH IN ONLY FLOAT IN STR TYPE CASTING
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 float('raj')
#
# ValueError: could not convert string to float: 'raj'

# %% [raw]
# => BOOL TO ALL OTHER DATA TYPES
# ***  VERY IMPORTANT IN FURTHER ALSO ***
# *** EVERY NON-ZERO ELEMENT IS TRUE ***
# *** EVERY ZERO ELEMENT AND SPACE AND NONETYPE ELEMENT IS FALSE ***

# %%
bool(1)
# Out:
# True

# %%
bool(10)
# Out:
# True

# %%
bool(10.2)
# Out:
# True

# %%
bool('raj')
# Out:
# True

# %%
bool('1+3j')
# Out:
# True

# %%
bool(True)
# Out:
# True

# %%
bool(False)
# Out:
# False

# %%
bool(1+3j)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %%
bool( )
# Out:
# False

# %%
bool(None)
# Out:
# False

# %%
bool()
# Out:
# False

# %%
bool(@)
# Out:
#   Cell In[31], line 1
#     bool(@)
#          ^
# SyntaxError: invalid syntax

# %% [raw]
# => COMPLEX TO ALL OTHER DATA TYPES

# %%
complex(1)
# Out:
# (1+0j)

# %%
complex(100)
# Out:
# (100+0j)

# %%
complex(2.0)
# Out:
# (2+0j)

# %%
complex(True)
# Out:
# (1+0j)

# %%
complex(False)
# Out:
# 0j

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex('10.2')
