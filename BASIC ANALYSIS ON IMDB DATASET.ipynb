# %%
import pandas as pd

# %%
import matplotlib.pyplot as pl

# %%
import numpy as np

# %%
movies = pd.read_csv(r"C:\Users\Raj Vishwakarma\Downloads\MovieLens 20M Dataset\movie.csv")

# %%
movies.shape
# Out:
# (27278, 3)

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movies.head(5)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
tags = pd.read_csv(r"C:\Users\Raj Vishwakarma\Downloads\MovieLens 20M Dataset\tag.csv")

# %%
tags.shape
# Out:
# (465564, 4)

# %%
type(tags)
# Out:
# pandas.core.frame.DataFrame

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
tags.head(5)
# Out:
#    userId  movieId            tag            timestamp
# 0      18     4141    Mark Waters  2009-04-24 18:19:40
# 1      65      208      dark hero  2013-05-10 01:41:18
# 2      65      353      dark hero  2013-05-10 01:41:19
# 3      65      521  noir thriller  2013-05-10 01:39:43
# 4      65      592      dark hero  2013-05-10 01:41:18

# %%
ratings = pd.read_csv(r"C:\Users\Raj Vishwakarma\Downloads\MovieLens 20M Dataset\rating.csv")

# %%
type(ratings)
# Out:
# pandas.core.frame.DataFrame

# %%
ratings.columns
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
ratings.head(5)
# Out:
#    userId  movieId  rating            timestamp
# 0       1        2     3.5  2005-04-02 23:53:47
# 1       1       29     3.5  2005-04-02 23:31:16
# 2       1       32     3.5  2005-04-02 23:33:39
# 3       1       47     3.5  2005-04-02 23:32:07
# 4       1       50     3.5  2005-04-02 23:29:40

# %%
print(movies.columns)
print(ratings.columns)
print(tags.columns)
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
del ratings['timestamp']

# %%
print(ratings.columns)
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')

# %%
ratings.describe()
# Out:
#              userId       movieId        rating
# count  2.000026e+07  2.000026e+07  2.000026e+07
# mean   6.904587e+04  9.041567e+03  3.525529e+00
# std    4.003863e+04  1.978948e+04  1.051989e+00
# min    1.000000e+00  1.000000e+00  5.000000e-01
# 25%    3.439500e+04  9.020000e+02  3.000000e+00
# 50%    6.914100e+04  2.167000e+03  3.500000e+00
# 75%    1.036370e+05  4.770000e+03  4.000000e+00
# max    1.384930e+05  1.312620e+05  5.000000e+00

# %%
ratings.mean()
# Out:
# userId     69045.872583
# movieId     9041.567330
# rating         3.525529
# dtype: float64

# %%
ratings.min()
# Out:
# userId     1.0
# movieId    1.0
# rating     0.5
# dtype: float64

# %%
ratings.max()
# Out:
# userId     138493.0
# movieId    131262.0
# rating          5.0
# dtype: float64

# %%
ratings.corr()
# Out:
#            userId   movieId    rating
# userId   1.000000 -0.000850  0.001175
# movieId -0.000850  1.000000  0.002606
# rating   0.001175  0.002606  1.000000

# %%
ratings.std()
# Out:
# userId     40038.626653
# movieId    19789.477445
# rating         1.051989
# dtype: float64

# %%
print(ratings['rating']>10)
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 20000258    False
# 20000259    False
# 20000260    False
# 20000261    False
# 20000262    False
# Name: rating, Length: 20000263, dtype: bool

# %%
print(movies.isnull())
print(ratings.isnull())
print(tags.isnull())
# Out:
#        movieId  title  genres
# 0        False  False   False
# 1        False  False   False
# 2        False  False   False
# 3        False  False   False
# 4        False  False   False
# ...        ...    ...     ...
# 27273    False  False   False
# 27274    False  False   False
# 27275    False  False   False
# 27276    False  False   False
# 27277    False  False   False
#
# [27278 rows x 3 columns]
#           userId  movieId  rating
# 0          False    False   False
# 1          False    False   False
# 2          False    False   False
# 3          False    False   False
# 4          False    False   False
# ...          ...      ...     ...
# 20000258   False    False   False
# 20000259   False    False   False
# 20000260   False    False   False
# 20000261   False    False   False
# 20000262   False    False   False
#
# [20000263 rows x 3 columns]
#         userId  movieId    tag  timestamp
# 0        False    False  False      False
# ...
