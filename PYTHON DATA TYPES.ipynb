# %% [markdown]
# # ***PYTHON DATATYPES***

# %%
a=10
a,type(a)
# Out:
# (10, int)

# %%
a=10.9
a,type(a)
# Out:
# (10.9, float)

# %%
a=True
a,type(a)

b= False
a,b,type(b),type(a)
# Out:
# (True, False, bool, bool)

# %%
a=2+3j
a,type(a)
# Out:
# ((2+3j), complex)

# %%
a='HI MY NAME IS RAJ'



a,type(a)
# Out:
# ('HI MY NAME IS RAJ', str)

# %%
b="HI MY NAME IS RAJ"

b,type(b)
# Out:
# ('HI MY NAME IS RAJ', str)

# %%
c=''' HI MY NAME IS RAJ
    I am currently working on Python Variables.'''

c,type(c)
# Out:
# (' HI MY NAME IS RAJ\n    I am currently working on Python Variables.', str)

# %%
d= """ HI MY NAME IS RAJ
       I am currently working on Python Variables."""

d,type(d)
# Out:
# (' HI MY NAME IS RAJ\n       I am currently working on Python Variables.', str)

# %%
a=range(10)
for i in a:
  print(i,type(i))
# Out:
# 0 <class 'int'>
# 1 <class 'int'>
# 2 <class 'int'>
# 3 <class 'int'>
# 4 <class 'int'>
# 5 <class 'int'>
# 6 <class 'int'>
# 7 <class 'int'>
# 8 <class 'int'>
# 9 <class 'int'>

# %%
a=[10,'Raj',"Python",10.7,True,2+3j]
print(a,type(a))
# Out:
# [10, 'Raj', 'Python', 10.7, True, (2+3j)] <class 'list'>

# %%
a=(10,20,30,2.2)
print(a,type(a))
# Out:
# (10, 20, 30, 2.2) <class 'tuple'>

# %%
a={100,200,"Raj"}
print(a,type(a))
# Out:
# {200, 100, 'Raj'} <class 'set'>

# %%
a={"Raj":100,"Python":200}
print(a,type(a))
# Out:
# {'Raj': 100, 'Python': 200} <class 'dict'>

# %%
a=None
print(a,type(a))
# Out:
# None <class 'NoneType'>
